# %% [markdown]
# # Load the data

# %%
import pandas as pd
print(pd)
# Out:
# <module 'pandas' from 'C:\\Users\\User\\Desktop\\Explore\\Udemy-Newt\\Courses\\Python\\Python_mega_course_in_60_Day\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
print("haii")
# Out:
# haii

# %%
df = pd.read_csv("TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\Explore\\Udemy-Newt\\Courses\\Python\\Python_mega_course_in_60_Day\\jupyter\\sample_data'

# %%
print(df)
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df[:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 0       1   35381 1860-01-01     21      0
# 1       1   35381 1860-01-02     46      0
# 2       1   35381 1860-01-03     31      0
# 3       1   35381 1860-01-04     37      0
# 4       1   35381 1860-01-05     31      0
# 5       1   35381 1860-01-06     16      0
# 6       1   35381 1860-01-07      5      0
# 7       1   35381 1860-01-08    -27      0
# 8       1   35381 1860-01-09     -4      0
# 9       1   35381 1860-01-10    -17      0
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
df['   TG'].mean()  # container the non data -as -9999
df.loc[df['   TG'] != -9999]['   TG'].mean() /10
df.loc[df['   TG'] != -9999]['   TG'].max() /10
# Out:
# np.float64(26.2)

# %%
df.loc[df['   TG'] != -9999]['   TG'].mean() /10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.loc[df['   TG']]
#
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
# ...

# %%
df.loc[df['    DATE'] == "1860-01-01"]['    TG']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '    TG'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ...

# %%
df.loc[df['   TG'] != -9999]['   TG'].hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.loc[df['   TG'] != -9999]['   TG'].hist()
#
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\plotting\_core.py:128, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      47 def hist_series(
#      48     self: Series,
#      49     by=None,
#    (...)     60     **kwargs,
#      61 ):
#      62     """
#      63     Draw histogram of the input series using matplotlib.
#      64
#    (...)    126         >>> hist = ser.groupby(level=0).hist()
#     127     """
# --> 128     plot_backend = _get_plot_backend(backend)
#     129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#    (...)    141         **kwargs,
#     142     )
#
# ...

# %%
df.loc[df['    DATE'] == date]['   TG'].squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.loc[df['    DATE'] == date]['   TG'].squeeze()
#
# NameError: name 'date' is not defined

# %%
df.loc[df['    DATE']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.loc[df['    DATE']]
#
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\Explore\Udemy-Newt\Courses\Python\Python_mega_course_in_60_Day\.venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
# ...

# %%
df.loc[df['    DATE'] == "1860-01-01"]['   TG'].squeeze()
# Out:
# np.int64(21)
